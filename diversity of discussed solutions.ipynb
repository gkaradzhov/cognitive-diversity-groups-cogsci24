# %%
import plotly.io as pio
import plotly.express as px
import plotly.subplots as pss
import plotly.graph_objects as go
pio.templates.default = "plotly_white"
COLOUR_CONTINIOUS_SCALE="bluered"

# The one below should be both color-blind and print friendly. It's based on: https://colorbrewer2.org/#type=sequential&scheme=RdPu&n=5
COLOUR_ARRAY = ["#feebe2", "#fbb4b9", "#f768a1", "#c51b8a", "#7a0177"]

# %%
import plotly.io as pio
pio.renderers.default = 'iframe'

# %%
from scipy import stats
import numpy as np
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
import pandas as pd

# %%
from collections import defaultdict
import csv

# %%
from delitoolkit.delidata import DeliData

# %%
d = DeliData().corpus

# %%
allowed = {
    'vowels': {'A', 'O', 'U', 'E', 'I', 'Y'},
    'consonants': {'B', 'C', 'D', 'F', 'G', 'H', 'J', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'X', 'Z', 'W'},
    'odds': {'1', '3', '5', '7', '9'},
    'evens': {'0', '2', '4', '6', '8'}
}

def process_solution_simple(solution):
    res = set()
    for item in solution:
        for a_k, a_v in allowed.items():
            if item in a_v:
                res.update(a_k[0])
    return "".join(sorted(list(res)))

# %%
exclude_9_correct = []

# %%
from collections import Counter
all_sols_counter = Counter()

# %%
import json

# %%
list_of_keys = sorted(list(d.keys()))
# exclude_9_correct = ["ec8896c6-56fb-4187-a932-92ac6bbd6f49", "c47d75d6-98f9-4a03-a0b1-54b341849ffc", "e731d8d4-d6f3-44ca-9d04-0d2caa2f0111", "02972b77-c909-499e-8d4b-8920a25707f0", "b1d5c668-eb55-440a-ade6-155784bcd0a4", "28e38a3c-0298-4585-b05f-cef4968f56c1", "f052602b-0dbe-45f8-8407-f0887616ad41", "dca3b7c4-9483-4d9d-b76b-b7244cd8529a", "513c227d-c2c2-4eb6-8730-feb1d513cbc1"]

# %%
all_transitions = defaultdict(lambda: defaultdict(lambda: 0))
bi_transitions = defaultdict(lambda: defaultdict(lambda: 0))
all_sols = 0
in_count = 0

for room_id in list_of_keys:
    if room_id in exclude_9_correct:
        continue
    room = d[room_id]
    sol_transition = []
    for room_message in room:
        if room_message['message_type'] == 'MESSAGE' and len(room_message['sol_tracker_message']) != 0:
            key_sols = process_solution_simple(room_message['sol_tracker_message'].split(','))
            sol_transition.append(key_sols)
    all_sols_counter.update(sol_transition)
    if len(sol_transition) < 3:
        all_transitions[room_id][">".join(sol_transition)] = 0
    else:
        grams = [sol_transition[i: i + 3] for i in range(len(sol_transition) - 3 + 1)]
        for prev, curr, nxt in grams:
            in_count += 1
            all_transitions[room_id][prev + ">" + curr + ">" + nxt] += 1
    if len(sol_transition) < 3:
        pass
    else:
        grams = [sol_transition[i: i + 2] for i in range(len(sol_transition) - 2 + 1)]
        for prev, nxt in grams:
            bi_transitions[room_id][prev + ">" + nxt] += 1

# %%
all_sols_counter.most_common(5)
# Out:
# [('v', 1217), ('ceov', 1036), ('ev', 990), ('ov', 788), ('e', 596)]

# %%
all_transitions
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'00639b9b-3a45-4c59-90f6-a4738de92fd4': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>o>c': 1,
#                           'o>c>v': 1,
#                           'c>v>c': 1,
#                           'v>c>ev': 1,
#                           'c>ev>ov': 1,
#                           'ev>ov>ev': 1,
#                           'ov>ev>v': 1,
#                           'ev>v>v': 1,
#                           'v>v>ov': 1,
#                           'v>ov>e': 1,
#                           'ov>e>ov': 1,
#                           'e>ov>ev': 1,
#                           'ov>ev>e': 1,
#                           'ev>e>o': 1,
#                           'e>o>e': 1,
#                           'o>e>e': 1}),
#              '0128a2aa-53a2-4874-8bfe-b71ce287e7c2': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'e>ov>ev': 1,
#                           'ov>ev>v': 1,
#                           'ev>v>v': 1,
#                           'v>v>ev': 1,
#                           'v>ev>ov': 1,
#                           'ev>ov>ev': 1,
#                           'ov>ev>ceov': 1,
#                           'ev>ceov>e': 1,
#                           'ceov>e>ev': 1,
#                           'e>ev>ceov': 1,
#                           'ev>ceov>v': 1,
#                           'ceov>v>o': 1,
#                           'v>o>v': 1,
#                           'o>v>ev': 1,
#                           'v>ev>ev': 1,
#                           'ev>ev>eo': 1,
#                           'ev>eo>o': 1,
#                           'eo>o>ceov': 1,
#                           'o>ceov>ov': 1,
#                           'ceov>ov>ceov': 1,
#                           'ov>ceov>ov': 1,
#                           'ceov>ov>o': 1,
#                           'ov>o>e': 1,
#                           'o>e>ov': 1,
#                           'e>ov>v': 1,
#                           'ov>v>ceov': 1}),
#              '01acf3e3-714c-4d53-9b74-9170a645bcd0': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>ev>ov': 1,
#                           'ev>ov>ceov': 1,
#                           'ov>ceov>c': 1,
#                           'ceov>c>co': 1,
#                           'c>co>v': 1,
#                           'co>v>v': 1,
#                           'v>v>eov': 1,
#                           'v>eov>ceov': 1}),
#              '01e7d47c-8831-4492-abb0-88f94c7b02a3': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>ev>ceov': 1,
#                           'ev>ceov>v': 1,
#                           'ceov>v>v': 1,
#                           'v>v>v': 1,
#                           'v>v>cv': 1,
#                           'v>cv>c': 1,
#                           'cv>c>ev': 1,
#                           'c>ev>cv': 1,
#                           'ev>cv>eov': 1,
#                           'cv>eov>eov': 1,
#                           'eov>eov>e': 1,
#                           'eov>e>ov': 1,
#                           'e>ov>e': 1,
#                           'ov>e>ov': 1,
#                           'e>ov>ev': 1,
#                           'ov>ev>ov': 1}),
#              '02972b77-c909-499e-8d4b-8920a25707f0': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ov>ov>ov': 1,
#                           'ov>ov>ceov': 1,
#                           'ov>ceov>c': 1,
#                           'ceov>c>ev': 1,
#                           'c>ev>ev': 1,
#                           'ev>ev>e': 1,
#                           'ev>e>eov': 1,
#                           'e>eov>ceov': 1,
#                           'eov>ceov>ov': 1,
#                           'ceov>ov>e': 1,
#                           'ov>e>ov': 3,
#                           'e>ov>e': 2}),
#              '03714d9c-9c47-4103-9b61-ed51c76e1ef6': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'e>eo>ev': 1,
#                           'eo>ev>eo': 1,
#                           'ev>eo>ev': 1,
#                           'eo>ev>o': 1,
#                           'ev>o>ev': 1,
#                           'o>ev>o': 1,
#                           'ev>o>o': 1,
#                           'o>o>ev': 1,
#                           'o>ev>ev': 1,
#                           'ev>ev>ev': 1}),
#              '038c3e5e-35bf-4e26-b96d-8ff92bb8c830': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>ev>c': 1,
#                           'ev>c>o': 1,
#                           'c>o>ov': 1,
#                           'o>ov>o': 1,
#                           'ov>o>ov': 1}),
#              '04edccd6-25d7-47dc-b73f-5bce9d77025b': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ov>e>v': 1,
#                           'e>v>e': 1,
#                           'v>e>ceov': 1,
#                           'e>ceov>e': 2,
#                           'ceov>e>ceov': 1,
#                           'ceov>e>v': 1,
#                           'e>v>o': 1,
#                           'v>o>e': 1,
#                           'o>e>e': 1,
#                           'e>e>v': 1,
#                           'e>v>v': 1,
#                           'v>v>v': 1}),
#              '05627bda-cc61-43bb-833f-90e6140074dc': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>ceov>ev': 1,
#                           'ceov>ev>v': 1,
#                           'ev>v>ceov': 1,
#                           'v>ceov>ceov': 2,
#                           'ceov>ceov>v': 2,
#                           'ceov>v>v': 2,
#                           'v>v>ceov': 1,
#                           'ceov>ceov>ceov': 2,
#                           'v>v>ev': 1,
#                           'v>ev>ceov': 1,
#                           'ev>ceov>ov': 1,
#                           'ceov>ov>ceov': 1,
#                           'ov>ceov>ceov': 1,
#                           'ceov>ceov>o': 1,
#                           'ceov>o>cv': 1}),
#              '05b01d11-9edb-41b7-a330-cf21fa421183': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>e>e': 1,
#                           'e>e>v': 1,
#                           'e>v>ev': 1,
#                           'v>ev>v': 2,
#                           'ev>v>ev': 1,
#                           'ev>v>e': 1,
#                           'v>e>ev': 1,
#                           'e>ev>co': 1,
#                           'ev>co>v': 1,
#                           'co>v>v': 1,
#                           'v>v>ev': 1,
#                           'v>ev>ceov': 1,
#                           'ev>ceov>v': 1}),
#              '0610068a-0d3d-4fc2-a81b-94a74454700a': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'cv>cv>cev': 1,
#                           'cv>cev>v': 1,
#                           'cev>v>ev': 1,
#                           'v>ev>ev': 1}),
#              '0686b2d0-dddc-4052-92b2-2c274f3e4def': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>ev>v': 1,
#                           'ev>v>v': 1,
#                           'v>v>cv': 1,
#                           'v>cv>v': 1,
#                           'cv>v>e': 1,
#                           'v>e>o': 1,
#                           'e>o>ov': 1,
#                           'o>ov>eov': 1,
#                           'ov>eov>e': 1,
#                           'eov>e>ev': 1,
#                           'e>ev>o': 1,
#                           'ev>o>o': 1,
#                           'o>o>ov': 1,
#                           'o>ov>ov': 1,
#                           'ov>ov>e': 1,
#                           'ov>e>e': 1}),
#              '069dce94-a359-41a6-afb5-d9d074c7fcc3': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>ceov>v': 1,
#                           'ceov>v>ceov': 1,
#                           'v>ceov>ceov': 1,
#                           'ceov>ceov>ev': 1,
#                           'ceov>ev>v': 1,
#                           'ev>v>ev': 1,
#                           'v>ev>o': 1,
#                           'ev>o>o': 1,
#                           'o>o>o': 1,
#                           'o>o>c': 1,
#                           'o>c>e': 1,
#                           'c>e>e': 1,
#                           'e>e>c': 1,
#                           'e>c>ev': 1,
#                           'c>ev>o': 1,
#                           'ev>o>v': 1,
#                           'o>v>ev': 1,
#                           'v>ev>ceov': 1,
#                           'ev>ceov>eov': 1,
#                           'ceov>eov>v': 1,
#                           'eov>v>e': 1,
#                           'v>e>ov': 1}),
#              '06d658f6-d0ad-4fef-9a1c-6353b9700f18': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>ev>eov': 1,
#                           'ev>eov>ceov': 1,
#                           'eov>ceov>ov': 1,
#                           'ceov>ov>ov': 2,
#                           'ov>ov>o': 1,
#                           'ov>o>o': 1,
#                           'o>o>o': 1,
#                           'o>o>v': 1,
#                           'o>v>o': 1,
#                           'v>o>c': 1,
#                           'o>c>c': 1,
#                           'c>c>ov': 1,
#                           'c>ov>ceov': 1,
#                           'ov>ceov>ov': 1,
#                           'ov>ov>eov': 1,
#                           'ov>eov>eov': 1,
#                           'eov>eov>eov': 1,
#                           'eov>eov>ceov': 1,
#                           'eov>ceov>eov': 1}),
#              '07160ace-1991-462a-a52e-81fb44a6c59a': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ov>ov>ov': 1,
#                           'ov>ov>v': 2,
#                           'ov>v>v': 1,
#                           'v>v>ov': 1,
#                           'v>ov>ov': 1}),
#              '071d0952-edd7-4fed-9d76-6add6632e68e': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>ov>ce': 1,
#                           'ov>ce>ce': 1,
#                           'ce>ce>e': 1,
#                           'ce>e>cov': 1,
#                           'e>cov>ov': 1,
#                           'cov>ov>ov': 1,
#                           'ov>ov>v': 1,
#                           'ov>v>eov': 1,
#                           'v>eov>o': 1,
#                           'eov>o>ev': 1,
#                           'o>ev>eov': 1,
#                           'ev>eov>ov': 1}),
#              '074de597-b9e9-4186-ae35-261cc8ef46f7': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>ev>ceov': 1,
#                           'ev>ceov>ov': 1,
#                           'ceov>ov>ov': 2,
#                           'ov>ov>ov': 2,
#                           'ov>ov>ceov': 1,
#                           'ov>ceov>ce': 1,
#                           'ceov>ce>ov': 1,
#                           'ce>ov>v': 1,
#                           'ov>v>cv': 1,
#                           'v>cv>e': 1,
#                           'cv>e>ov': 1,
#                           'e>ov>ceov': 1,
#                           'ov>ceov>ceov': 1,
#                           'ceov>ceov>ov': 1,
#                           'ov>ov>co': 1,
#                           'ov>co>c': 1,
#                           'co>c>v': 1,
#                           'c>v>v': 1,
#                           'v>v>co': 1}),
#              '083f6017-4c39-43be-8687-31f5a901717b': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>ov>o': 1,
#                           'ov>o>ev': 1,
#                           'o>ev>e': 1,
#                           'ev>e>v': 1,
#                           'e>v>ov': 1,
#                           'v>ov>ceov': 1}),
#              '0884e8f0-ca8f-413a-9455-f166a0ad67d8': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>v>ov': 1, 'v>ov>o': 1, 'ov>o>e': 1, 'o>e>c': 1}),
#              '08c890ac-c67f-4be7-aaba-8c3f31c8abc1': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'e>v>ev': 1,
#                           'v>ev>ceov': 1,
#                           'ev>ceov>ceov': 1,
#                           'ceov>ceov>o': 2,
#                           'ceov>o>v': 1,
#                           'o>v>ceov': 1,
#                           'v>ceov>ceov': 1,
#                           'ceov>o>ov': 1,
#                           'o>ov>ov': 1}),
#              '08f1f827-f181-403b-9e1d-0843a43e8a65': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'co>ev>ce': 1,
#                           'ev>ce>c': 1,
#                           'ce>c>cev': 1,
#                           'c>cev>v': 1,
#                           'cev>v>ev': 1,
#                           'v>ev>ev': 1}),
#              '09b321d6-e6b9-446a-96af-79d89d66d71d': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'c>ov>c': 1,
#                           'ov>c>c': 1,
#                           'c>c>c': 1,
#                           'c>c>ov': 1,
#                           'c>ov>v': 1,
#                           'ov>v>ov': 1,
#                           'v>ov>ov': 1,
#                           'ov>ov>o': 1,
#                           'ov>o>cev': 1}),
#              '0a057d01-a7d0-4028-9daf-c71751339d16': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>v>v': 1,
#                           'v>v>v': 2,
#                           'v>v>ceov': 1,
#                           'v>ceov>v': 1}),
#              '0aeeb8d8-c358-46c5-a181-5d4f0b6f1d95': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>c>o': 1,
#                           'c>o>ceov': 1,
#                           'o>ceov>ceov': 1,
#                           'ceov>ceov>ceov': 1}),
#              '0b1354b8-4d4b-4b50-ab1e-3d1e7d9ac780': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>ceov>v': 1,
#                           'ceov>v>v': 1,
#                           'v>v>ov': 1,
#                           'v>ov>ov': 1,
#                           'ov>ov>o': 1,
#                           'ov>o>ceov': 1,
#                           'o>ceov>ceov': 2,
#                           'ceov>ceov>c': 1,
#                           'ceov>c>ev': 1,
#                           'c>ev>ov': 1,
#                           'ev>ov>eo': 1,
#                           'ov>eo>e': 1,
#                           'eo>e>e': 1,
#                           'e>e>o': 1,
#                           'e>o>ceov': 1,
#                           'ceov>ceov>ceov': 1,
#                           'ceov>ceov>e': 1,
#                           'ceov>e>ceov': 1,
#                           'e>ceov>ceov': 1}),
#              '0b37e6fb-eb3b-4c65-a886-2f9be44d5380': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ov>ev>eov': 1,
#                           'ev>eov>o': 1,
#                           'eov>o>o': 1,
#                           'o>o>e': 1,
#                           'o>e>ov': 1,
#                           'e>ov>ceov': 1}),
#              '0b8fe30f-2304-48aa-a3ed-f80e45ea9024': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>ov>ceov': 1,
#                           'ov>ceov>e': 1,
#                           'ceov>e>v': 1,
#                           'e>v>ov': 1,
#                           'v>ov>ov': 1,
#                           'ov>ov>ceov': 1,
#                           'ov>ceov>ov': 1,
#                           'ceov>ov>ov': 1}),
#              '0cac5462-55f1-4a16-954c-0e7351652e53': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'e>ev>co': 1,
#                           'ev>co>cov': 1,
#                           'co>cov>o': 1,
#                           'cov>o>ov': 1,
#                           'o>ov>c': 1,
#                           'ov>c>c': 1,
#                           'c>c>c': 1,
#                           'c>c>o': 1,
#                           'c>o>eov': 1,
#                           'o>eov>ceov': 1,
#                           'eov>ceov>ov': 1,
#                           'ceov>ov>eov': 1,
#                           'ov>eov>ov': 1,
#                           'eov>ov>e': 1,
#                           'ov>e>e': 1,
#                           'e>e>ceov': 1}),
#              '0d3e5966-6120-4bf3-a51e-e979f635819b': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>ov>o': 1,
#                           'ov>o>o': 1,
#                           'o>o>o': 1,
#                           'o>o>ev': 1,
#                           'o>ev>ceov': 1,
#                           'ev>ceov>e': 1,
#                           'ceov>e>c': 1,
#                           'e>c>ceov': 1,
#                           'c>ceov>ov': 1,
#                           'ceov>ov>v': 1,
#                           'ov>v>o': 1,
#                           'v>o>c': 1,
#                           'o>c>ceov': 1,
#                           'c>ceov>ceov': 1}),
#              '0d908396-4045-42af-9f1c-8b06ac2c0788': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'c>ev>e': 1,
#                           'ev>e>v': 1,
#                           'e>v>cv': 1,
#                           'v>cv>cev': 1,
#                           'cv>cev>ce': 1,
#                           'cev>ce>ce': 1,
#                           'ce>ce>eov': 1,
#                           'ce>eov>cv': 1,
#                           'eov>cv>cv': 1,
#                           'cv>cv>cv': 1,
#                           'cv>cv>ceov': 1,
#                           'cv>ceov>cv': 1,
#                           'ceov>cv>ov': 1}),
#              '0fe49822-69a3-488b-856d-436cb9d8d45f': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ov>ev>ev': 2,
#                           'ev>ev>ev': 1,
#                           'ev>ev>ceov': 1,
#                           'ev>ceov>ov': 1,
#                           'ceov>ov>ev': 1,
#                           'ev>ev>co': 1,
#                           'ev>co>ov': 1,
#                           'co>ov>v': 1}),
#              '10c68bbd-686a-4414-b4f5-ceb1195aa22f': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ov>ov>ce': 1,
#                           'ov>ce>ceov': 1,
#                           'ce>ceov>c': 1,
#                           'ceov>c>c': 1,
#                           'c>c>ov': 1,
#                           'c>ov>e': 1}),
#              '11934dc8-3b54-4ebf-aa12-3c7272a0e14e': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>v>ov': 1, 'v>ov>v': 1, 'ov>v>eov': 1}),
#              '11b42793-338f-4fe7-a790-fb50bf2408bb': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>ev>v': 1, 'ev>v>ev': 1, 'v>ev>ev': 1}),
#              '12924100-f2c3-487e-83c0-bc3dedd16f2e': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ov>ov>ceov': 1,
#                           'ov>ceov>v': 1,
#                           'ceov>v>ev': 2,
#                           'v>ev>co': 1,
#                           'ev>co>ce': 1,
#                           'co>ce>co': 1,
#                           'ce>co>ov': 1,
#                           'co>ov>ev': 1,
#                           'ov>ev>o': 1,
#                           'ev>o>v': 1,
#                           'o>v>ev': 1,
#                           'v>ev>v': 1,
#                           'ev>v>ev': 1,
#                           'v>ev>ov': 1,
#                           'ev>ov>o': 1,
#                           'ov>o>ov': 1,
#                           'o>ov>ov': 1,
#                           'ov>ov>v': 1,
#                           'ov>v>ceov': 1,
#                           'v>ceov>ceov': 1,
#                           'ceov>ceov>ceov': 2,
#                           'ceov>ceov>v': 1,
#                           'v>ev>cov': 1,
#                           'ev>cov>ev': 1,
#                           'cov>ev>ov': 1,
#                           'ev>ov>ev': 1}),
#              '12c28a6c-9e54-445c-892a-48948864a0a4': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>eov>ov': 1,
#                           'eov>ov>ev': 1,
#                           'ov>ev>v': 1,
#                           'ev>v>v': 1,
#                           'v>v>v': 1,
#                           'v>v>ov': 1,
#                           'v>ov>ov': 1,
#                           'ov>ov>c': 1,
#                           'ov>c>ceov': 1,
#                           'c>ceov>ov': 1,
#                           'ceov>ov>ceov': 1}),
#              '133533c6-b57c-4af3-b883-bcabebf64c0a': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>ceov>ev': 1,
#                           'ceov>ev>ev': 1,
#                           'ev>ev>ev': 2,
#                           'ev>ev>ceov': 1,
#                           'ev>ceov>o': 1,
#                           'ceov>o>v': 1,
#                           'o>v>o': 1,
#                           'v>o>o': 1,
#                           'o>o>v': 1,
#                           'o>v>ov': 1,
#                           'v>ov>ev': 1,
#                           'ov>ev>ev': 1,
#                           'ev>ev>cov': 1,
#                           'ev>cov>ev': 1,
#                           'cov>ev>ev': 1}),
#              '137068ab-319c-4b53-90b5-1b6bb5036644': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>ceov>co': 1,
#                           'ceov>co>ceov': 1,
#                           'co>ceov>cv': 1,
#                           'ceov>cv>o': 1,
#                           'cv>o>ceov': 1,
#                           'o>ceov>ceov': 1,
#                           'ceov>ceov>eov': 1,
#                           'ceov>eov>o': 1,
#                           'eov>o>v': 1,
#                           'o>v>o': 1,
#                           'v>o>ev': 1,
#                           'o>ev>ceov': 1,
#                           'ev>ceov>ov': 1,
#                           'ceov>ov>o': 1,
#                           'ov>o>eov': 1,
#                           'o>eov>ceov': 1,
#                           'eov>ceov>c': 1}),
#              '15171c24-cf47-4e89-82e2-6d56b88ce3a4': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'e>e>o': 1,
#                           'e>o>o': 2,
#                           'o>o>e': 1,
#                           'o>e>o': 1,
#                           'o>o>ceov': 1,
#                           'o>ceov>e': 1,
#                           'ceov>e>o': 1,
#                           'e>o>e': 1,
#                           'o>e>e': 1,
#                           'e>e>ev': 1}),
#              '15295929-9497-4e84-8827-ae258aa691fa': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>v>c': 1,
#                           'v>c>o': 1,
#                           'c>o>ev': 1,
#                           'o>ev>ev': 1,
#                           'ev>ev>ceov': 1}),
#              '15c6f080-0814-4865-bace-d52b771d10eb': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>ceov>v': 1,
#                           'ceov>v>v': 1,
#                           'v>v>ev': 2,
#                           'v>ev>ev': 1,
#                           'ev>ev>e': 1,
#                           'ev>e>ceov': 1,
#                           'e>ceov>ev': 1,
#                           'ceov>ev>v': 1,
#                           'ev>v>v': 2,
#                           'v>v>v': 5,
#                           'v>ev>v': 1}),
#              '165291fb-80b1-42df-b8a2-d5e743bd0113': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>ceov>ev': 1,
#                           'ceov>ev>ev': 2,
#                           'ev>ev>ceov': 1,
#                           'ev>ceov>ev': 1,
#                           'ev>ev>v': 1,
#                           'ev>v>ceov': 1}),
#              '17620ae0-2f24-4b14-a2d3-ed338610015e': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ov>ceov>e': 1,
#                           'ceov>e>eov': 1,
#                           'e>eov>e': 1,
#                           'eov>e>e': 1,
#                           'e>e>ov': 1,
#                           'e>ov>ceov': 1}),
#              '17d41934-42a7-4bb3-aebf-c6cf7ba3ce52': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>ev>ceov': 1,
#                           'ev>ceov>e': 1,
#                           'ceov>e>ceov': 1,
#                           'e>ceov>ceov': 2,
#                           'ceov>ceov>ceov': 10,
#                           'ceov>ceov>ceo': 1,
#                           'ceov>ceo>ceov': 1,
#                           'ceo>ceov>ceov': 1,
#                           'ceov>ceov>e': 1,
#                           'ceov>e>e': 1,
#                           'e>e>ceov': 1}),
#              '17d8ea73-7c67-4e17-b0d3-9a45e1f64aad': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>ev>co': 1,
#                           'ev>co>ceov': 1,
#                           'co>ceov>v': 1,
#                           'ceov>v>ceov': 1,
#                           'v>ceov>ceov': 1,
#                           'ceov>ceov>ceov': 1,
#                           'ceov>ceov>co': 1}),
#              '17f99c99-8d93-4102-9767-9b0a5d26f2d8': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ov>ceov>v': 1,
#                           'ceov>v>ceov': 1,
#                           'v>ceov>e': 1,
#                           'ceov>e>ov': 1,
#                           'e>ov>v': 1,
#                           'ov>v>v': 1,
#                           'v>v>c': 1,
#                           'v>c>c': 1,
#                           'c>c>e': 1,
#                           'c>e>c': 1,
#                           'e>c>e': 1,
#                           'c>e>e': 1,
#                           'e>e>o': 1,
#                           'e>o>eo': 1,
#                           'o>eo>v': 1,
#                           'eo>v>v': 1,
#                           'v>v>o': 1,
#                           'v>o>o': 1,
#                           'o>o>o': 2,
#                           'o>o>ceov': 1,
#                           'o>ceov>o': 1,
#                           'ceov>o>ov': 1,
#                           'o>ov>ce': 1,
#                           'ov>ce>ov': 1,
#                           'ce>ov>ceov': 1,
#                           'ov>ceov>ov': 1}),
#              '18400c84-c2a5-44d4-a4d3-73b9b0c108fa': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>ev>eov': 1,
#                           'ev>eov>ov': 1,
#                           'eov>ov>ceov': 1,
#                           'ov>ceov>co': 1,
#                           'ceov>co>ov': 1,
#                           'co>ov>eov': 1,
#                           'ov>eov>v': 1,
#                           'eov>v>v': 1,
#                           'v>v>v': 2,
#                           'v>v>ov': 1,
#                           'v>ov>v': 1,
#                           'ov>v>v': 1}),
#              '184b605f-6dc6-4685-b6c1-25f8748e0372': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ov>ev>ceov': 1, 'ev>ceov>e': 1, 'ceov>e>eov': 1}),
#              '18a27720-f3f3-4d27-9a17-970aa55acb10': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev': 0}),
#              '18f40f8c-bf2a-4e59-bf21-ee466224a0b1': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'co>v>ceov': 1,
#                           'v>ceov>e': 1,
#                           'ceov>e>e': 1,
#                           'e>e>e': 1,
#                           'e>e>ceov': 1,
#                           'e>ceov>v': 1,
#                           'ceov>v>v': 1,
#                           'v>v>v': 2,
#                           'v>v>ceov': 1,
#                           'v>ceov>v': 1,
#                           'ceov>v>co': 1,
#                           'v>co>co': 1,
#                           'co>co>o': 1,
#                           'co>o>ov': 1,
#                           'o>ov>v': 1,
#                           'ov>v>ov': 2,
#                           'v>ov>ev': 1,
#                           'ov>ev>ov': 1,
#                           'ev>ov>ov': 1,
#                           'ov>ov>v': 1,
#                           'v>ov>ov': 1,
#                           'ov>ov>ov': 3}),
#              '19494ac6-8c27-4b65-9ae6-0da45e33601a': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>v>ev': 1, 'v>ev>v': 1, 'ev>v>v': 1, 'v>v>v': 1}),
#              '19cae306-3bcb-4a1e-9ab4-8c5ac9590bd1': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>e>v': 1,
#                           'e>v>e': 1,
#                           'v>e>ov': 1,
#                           'e>ov>o': 1,
#                           'ov>o>e': 1,
#                           'o>e>v': 1,
#                           'e>v>v': 1,
#                           'v>v>ev': 1,
#                           'v>ev>v': 1,
#                           'ev>v>ov': 1}),
#              '19e81a26-1344-4a5c-886f-a2d4ca5eb283': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>v>ceov': 1}),
#              '1adfd9cb-a10c-4f16-a880-29a0c7be304c': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>e>ev': 1,
#                           'e>ev>ceov': 1,
#                           'ev>ceov>v': 1,
#                           'ceov>v>co': 1,
#                           'v>co>v': 1,
#                           'co>v>ev': 1,
#                           'v>ev>v': 1,
#                           'ev>v>v': 1}),
#              '1af2b204-c003-4a56-bd19-d8bd242f94d2': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>ceov>ceov': 3,
#                           'ceov>ceov>e': 1,
#                           'ceov>e>ceov': 1,
#                           'e>ceov>ceov': 1}),
#              '1b5d065a-0518-4ac6-9f1e-7ff46107e079': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'co>ev>ev': 1,
#                           'ev>ev>o': 1,
#                           'ev>o>ov': 1,
#                           'o>ov>cov': 1,
#                           'ov>cov>e': 1,
#                           'cov>e>eov': 1,
#                           'e>eov>e': 1,
#                           'eov>e>eov': 1,
#                           'e>eov>ce': 1,
#                           'eov>ce>e': 1,
#                           'ce>e>ov': 1}),
#              '1baa2258-587b-4408-bf85-d40ba0a8a564': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>ev>v': 1,
#                           'ev>v>ev': 1,
#                           'v>ev>c': 1,
#                           'ev>c>ceov': 1,
#                           'c>ceov>ceov': 1,
#                           'ceov>ceov>cov': 1,
#                           'ceov>cov>ceov': 1,
#                           'cov>ceov>ceov': 1,
#                           'ceov>ceov>ceov': 1}),
#              '1c5fc2bc-6432-40b7-b02b-89c51d46894e': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>ev>ceov': 1,
#                           'ev>ceov>ceov': 1,
#                           'ceov>ceov>e': 1,
#                           'ceov>e>ov': 1,
#                           'e>ov>v': 1,
#                           'ov>v>e': 1,
#                           'v>e>ev': 1,
#                           'e>ev>e': 1,
#                           'ev>e>e': 1,
#                           'e>e>e': 1,
#                           'e>e>co': 1,
#                           'e>co>o': 1,
#                           'co>o>co': 1,
#                           'o>co>v': 1,
#                           'co>v>ev': 1,
#                           'v>ev>co': 1,
#                           'ev>co>co': 1,
#                           'co>co>o': 1,
#                           'co>o>o': 1,
#                           'o>o>e': 2,
#                           'o>e>o': 1,
#                           'e>o>o': 1,
#                           'o>e>e': 1,
#                           'e>e>c': 1,
#                           'e>c>c': 1,
#                           'c>c>v': 1,
#                           'c>v>v': 1,
#                           'v>v>ov': 1,
#                           'v>ov>ov': 1}),
#              '1d490c0b-6192-48f0-8f7a-7ac3c4428ac6': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>v>ceov': 1,
#                           'v>ceov>e': 1,
#                           'ceov>e>v': 1,
#                           'e>v>ev': 1,
#                           'v>ev>ev': 1,
#                           'ev>ev>ov': 1,
#                           'ev>ov>ceov': 1,
#                           'ov>ceov>eov': 1,
#                           'ceov>eov>eov': 1,
#                           'eov>eov>eov': 1,
#                           'eov>eov>cv': 1,
#                           'eov>cv>eov': 1,
#                           'cv>eov>ov': 1}),
#              '1d557a87-fa76-4dba-b550-7ba5b5072915': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>v>e': 1,
#                           'v>e>e': 1,
#                           'e>e>v': 1,
#                           'e>v>v': 1,
#                           'v>v>ev': 1,
#                           'v>ev>ceov': 1}),
#              '1dcb5e1d-b6d7-4b60-8fac-716b53d3a848': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>ov>v': 1,
#                           'ov>v>ceov': 1,
#                           'v>ceov>v': 1,
#                           'ceov>v>o': 1,
#                           'v>o>c': 1,
#                           'o>c>ceov': 1,
#                           'c>ceov>ceov': 1,
#                           'ceov>ceov>ceov': 2}),
#              '1ee7269f-721d-47c2-a8e8-d786d253e940': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>ev>eo': 1,
#                           'ev>eo>eo': 1,
#                           'eo>eo>ev': 1,
#                           'eo>ev>ov': 1,
#                           'ev>ov>ov': 1,
#                           'ov>ov>eo': 1,
#                           'ov>eo>ov': 1,
#                           'eo>ov>ov': 1}),
#              '1f798e00-5575-45b5-ae30-a98964b2a609': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>v>ev': 1,
#                           'v>ev>e': 1,
#                           'ev>e>e': 1,
#                           'e>e>e': 1,
#                           'e>e>v': 1,
#                           'e>v>ceov': 1,
#                           'v>ceov>co': 1,
#                           'ceov>co>e': 1,
#                           'co>e>ov': 1,
#                           'e>ov>cov': 1,
#                           'ov>cov>e': 1,
#                           'cov>e>ceov': 1}),
#              '2004c992-ea0b-4566-b6d8-45dd4a048447': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>v>v': 2,
#                           'v>v>ev': 1,
#                           'v>ev>ev': 1,
#                           'ev>ev>ceov': 1,
#                           'ev>ceov>e': 1,
#                           'ceov>e>ov': 1,
#                           'e>ov>v': 1,
#                           'ov>v>ce': 1,
#                           'v>ce>ov': 1}),
#              '20947406-9883-40e1-a4da-c1891cd49ddf': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>ceov>co': 1,
#                           'ceov>co>e': 1,
#                           'co>e>v': 1,
#                           'e>v>ev': 1,
#                           'v>ev>ceov': 1,
#                           'ev>ceov>ev': 1,
#                           'ceov>ev>ev': 1,
#                           'ev>ev>ev': 1}),
#              '217085ef-42a5-4ea9-bb15-90743bff1c0b': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>v>v': 2,
#                           'v>v>ceo': 1,
#                           'v>ceo>co': 1,
#                           'ceo>co>cov': 1,
#                           'co>cov>ev': 1,
#                           'cov>ev>ev': 1,
#                           'ev>ev>v': 1,
#                           'ev>v>ceov': 1,
#                           'v>ceov>e': 1,
#                           'ceov>e>v': 1,
#                           'e>v>ceov': 1,
#                           'v>ceov>v': 2,
#                           'v>v>ceov': 2,
#                           'v>ceov>ev': 1,
#                           'ceov>ev>v': 1,
#                           'ev>v>v': 1,
#                           'v>v>v': 1,
#                           'ceov>v>ev': 1}),
#              '21d5aeec-9b09-4307-a49a-bfc91af16a19': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>e': 0}),
#              '21dc071c-0ea9-47b5-a519-2029d6578602': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>v>v': 2,
#                           'v>v>ceov': 1,
#                           'v>ceov>ceov': 1,
#                           'ceov>ceov>ceov': 1,
#                           'ceov>ceov>c': 1,
#                           'ceov>c>eov': 1,
#                           'c>eov>ov': 1,
#                           'eov>ov>c': 1,
#                           'ov>c>c': 1,
#                           'c>c>ceov': 1,
#                           'c>ceov>eov': 1,
#                           'ceov>eov>eov': 1,
#                           'eov>eov>ov': 1,
#                           'eov>ov>ev': 1,
#                           'ov>ev>v': 1,
#                           'v>v>eov': 1,
#                           'v>eov>eov': 1,
#                           'eov>eov>v': 1}),
#              '21e9c1c2-a682-4b65-9f7e-893b193aab5e': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ov>v>e': 1,
#                           'v>e>cv': 1,
#                           'e>cv>v': 1,
#                           'cv>v>c': 1,
#                           'v>c>ev': 1,
#                           'c>ev>o': 1,
#                           'ev>o>ov': 1,
#                           'o>ov>ov': 1}),
#              '222236d5-8d02-4864-8272-4340ffd05e5a': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>e>ov': 1,
#                           'e>ov>e': 1,
#                           'ov>e>o': 1,
#                           'e>o>o': 1,
#                           'o>o>o': 1,
#                           'o>o>e': 1,
#                           'o>e>o': 1,
#                           'e>o>v': 1,
#                           'o>v>v': 1,
#                           'v>v>e': 1,
#                           'v>e>e': 1,
#                           'e>e>ceov': 1,
#                           'e>ceov>e': 1,
#                           'ceov>e>v': 1,
#                           'e>v>o': 1,
#                           'v>o>ov': 1,
#                           'o>ov>ov': 1}),
#              '2381fe73-4fc9-45cd-b0ad-84327c70c48d': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>ov>e': 1,
#                           'ov>e>co': 1,
#                           'e>co>ov': 1,
#                           'co>ov>ev': 1}),
#              '24374117-8fff-4c7f-95a5-06e3f8d37c21': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>ov>v': 1,
#                           'ov>v>ev': 1,
#                           'v>ev>ceov': 1,
#                           'ev>ceov>v': 1,
#                           'ceov>v>e': 1,
#                           'v>e>ov': 1,
#                           'e>ov>v': 1,
#                           'ov>v>ov': 1,
#                           'v>ov>e': 1,
#                           'ov>e>e': 1,
#                           'e>e>c': 1,
#                           'e>c>ov': 1,
#                           'c>ov>ov': 1,
#                           'ov>ov>ceov': 1}),
#              '25081f71-3fd0-49b3-b27f-7fe78258bcaa': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>v>ov': 1,
#                           'v>ov>ceov': 1,
#                           'ov>ceov>ov': 1,
#                           'ceov>ov>e': 1,
#                           'ov>e>v': 1,
#                           'e>v>eo': 1,
#                           'v>eo>v': 1}),
#              '25f2fbd9-2c16-479e-b8bd-da911d0d91da': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>ceov>ev': 1,
#                           'ceov>ev>o': 2,
#                           'ev>o>c': 1,
#                           'o>c>ceov': 1,
#                           'c>ceov>ev': 1,
#                           'ev>o>eov': 1,
#                           'o>eov>c': 1,
#                           'eov>c>eov': 1,
#                           'c>eov>c': 1,
#                           'eov>c>o': 1,
#                           'c>o>c': 1,
#                           'o>c>eov': 1,
#                           'c>eov>ceov': 1}),
#              '260bd13b-306d-4ec3-b32d-55b9e9646905': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>ev>ov': 1,
#                           'ev>ov>o': 1,
#                           'ov>o>ceov': 1,
#                           'o>ceov>e': 1,
#                           'ceov>e>c': 1,
#                           'e>c>c': 1,
#                           'c>c>ov': 1}),
#              '271f24f2-4b6a-41fb-ad7b-f85fb8765a33': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>v>v': 7}),
#              '2788e8a9-eecf-4d92-af82-08d8b5ce1bf5': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>v>v': 1,
#                           'v>v>e': 1,
#                           'v>e>v': 1,
#                           'e>v>v': 1,
#                           'v>v>cv': 1,
#                           'v>cv>v': 1}),
#              '28a79969-cd41-4347-8c7b-a96231768a2a': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>ceov>ev': 1,
#                           'ceov>ev>ce': 1,
#                           'ev>ce>ov': 1,
#                           'ce>ov>ov': 1,
#                           'ov>ov>ov': 2,
#                           'ov>ov>e': 1,
#                           'ov>e>e': 1,
#                           'e>e>eov': 1}),
#              '28e38a3c-0298-4585-b05f-cef4968f56c1': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>v>e': 1, 'v>e>o': 1, 'e>o>o': 1, 'o>o>ceov': 1}),
#              '29211401-b102-472a-974c-206c02583686': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'cv>o>e': 1,
#                           'o>e>o': 1,
#                           'e>o>cv': 1,
#                           'o>cv>ceov': 1,
#                           'cv>ceov>ceov': 1,
#                           'ceov>ceov>o': 1,
#                           'ceov>o>ceov': 1,
#                           'o>ceov>ceov': 1}),
#              '2928690e-5301-4485-b6ee-b34d43bcedd0': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>v>ev': 1,
#                           'v>ev>ceov': 1,
#                           'ev>ceov>v': 1,
#                           'ceov>v>v': 1}),
#              '29d33e95-ad65-4c68-99c3-4ef0134d6730': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>e>ev': 1,
#                           'e>ev>ev': 1,
#                           'ev>ev>ev': 2,
#                           'ev>ev>o': 1,
#                           'ev>o>ceov': 1,
#                           'o>ceov>ceov': 1,
#                           'ceov>ceov>ov': 1}),
#              '2a1ea9c0-a8aa-438e-b8a7-fdb8e57d0636': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>e>ceov': 1,
#                           'e>ceov>e': 1,
#                           'ceov>e>c': 1,
#                           'e>c>v': 1}),
#              '2b20c864-a1ee-4b9b-9164-773078f47ae0': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>ceov>ceov': 1,
#                           'ceov>ceov>co': 1,
#                           'ceov>co>v': 1,
#                           'co>v>ceov': 1,
#                           'v>ceov>ev': 1,
#                           'ceov>ev>cv': 1,
#                           'ev>cv>eo': 1,
#                           'cv>eo>ceov': 1,
#                           'eo>ceov>co': 1,
#                           'ceov>co>o': 1,
#                           'co>o>ceov': 1,
#                           'o>ceov>c': 1,
#                           'ceov>c>ceov': 1}),
#              '2cddf5d7-dfe4-4913-a02d-0c7424e46ce9': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>eo>eo': 1,
#                           'eo>eo>eo': 1,
#                           'eo>eo>cv': 1,
#                           'eo>cv>v': 1,
#                           'cv>v>ceov': 1,
#                           'v>ceov>ceov': 1,
#                           'ceov>ceov>e': 2,
#                           'ceov>e>o': 1,
#                           'e>o>eo': 1,
#                           'o>eo>c': 1,
#                           'eo>c>ceov': 1,
#                           'c>ceov>e': 1,
#                           'ceov>e>ceov': 1,
#                           'e>ceov>ceov': 1,
#                           'ceov>e>e': 1,
#                           'e>e>e': 1}),
#              '2d43c5a8-a321-4def-834d-7214dc119256': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>ceov>cv': 1,
#                           'ceov>cv>ceov': 1,
#                           'cv>ceov>ceov': 1,
#                           'ceov>ceov>ceov': 1}),
#              '2d8bb928-e1b3-4e2b-87b1-a9c3e06be23c': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>ov>eo': 1,
#                           'ov>eo>ev': 1,
#                           'eo>ev>c': 1,
#                           'ev>c>c': 1,
#                           'c>c>o': 1,
#                           'c>o>c': 1,
#                           'o>c>o': 1,
#                           'c>o>o': 1,
#                           'o>o>ov': 1,
#                           'o>ov>ov': 1,
#                           'ov>ov>ov': 1,
#                           'ov>ov>v': 1,
#                           'ov>v>ov': 1}),
#              '2dcaa987-e015-4d2f-a8d2-4ca70d657d9d': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'e>v>ev': 1,
#                           'v>ev>ceov': 1,
#                           'ev>ceov>ov': 1,
#                           'ceov>ov>ev': 1,
#                           'ov>ev>e': 1,
#                           'ev>e>o': 1,
#                           'e>o>ov': 1,
#                           'o>ov>o': 1,
#                           'ov>o>co': 1,
#                           'o>co>ov': 1,
#                           'co>ov>ov': 1,
#                           'ov>ov>ov': 3,
#                           'ov>ov>v': 1,
#                           'ov>v>ceov': 1,
#                           'v>ceov>v': 1,
#                           'ceov>v>eo': 1,
#                           'v>eo>ceov': 1,
#                           'eo>ceov>ceov': 1,
#                           'ceov>ceov>ov': 1,
#                           'ceov>ov>ov': 1}),
#              '2e4ec628-8c4d-4058-83b0-f7142240fe7e': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>e>o': 1,
#                           'e>o>o': 1,
#                           'o>o>c': 1,
#                           'o>c>cv': 1,
#                           'c>cv>e': 1,
#                           'cv>e>o': 1,
#                           'e>o>v': 1,
#                           'o>v>ev': 1,
#                           'v>ev>ev': 1}),
#              '2ec384a1-b6b4-451c-a0c0-602275fcec5a': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>ceov>co': 1, 'ceov>co>ov': 1, 'co>ov>v': 1}),
#              '3075a4c5-c3b1-4772-bfe8-5518e0a7286f': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>ceov>ceov': 2,
# ...
#                           'cov>c>ev': 1,
#                           'c>ev>v': 1,
#                           'ev>v>ev': 1,
#                           'v>ev>v': 1,
#                           'ev>v>v': 1,
#                           'v>v>v': 3}),
#              'f632ed63-b2e1-4b0f-b57b-f042bbc0df4f': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'eov>cov>cv': 1,
#                           'cov>cv>v': 1,
#                           'cv>v>cv': 2,
#                           'v>cv>v': 1,
#                           'v>cv>cv': 1,
#                           'cv>cv>ceov': 1,
#                           'cv>ceov>ceov': 1,
#                           'ceov>ceov>v': 1,
#                           'ceov>v>cov': 1,
#                           'v>cov>v': 1,
#                           'cov>v>v': 1,
#                           'v>v>ceov': 1,
#                           'v>ceov>v': 1}),
#              'f68053f2-0e2b-4a69-a72c-767cf767d897': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>ev>e': 1,
#                           'ev>e>v': 1,
#                           'e>v>o': 1,
#                           'v>o>v': 1,
#                           'o>v>c': 1,
#                           'v>c>v': 1,
#                           'c>v>v': 1,
#                           'v>v>o': 1,
#                           'v>o>cv': 1,
#                           'o>cv>o': 1,
#                           'cv>o>ev': 1,
#                           'o>ev>v': 1,
#                           'ev>v>v': 1,
#                           'v>v>v': 2,
#                           'v>v>ceov': 2,
#                           'v>ceov>ceov': 1,
#                           'ceov>ceov>v': 1,
#                           'ceov>v>v': 1}),
#              'f7735a7d-ffea-41b9-b900-432aebd57a60': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>ev>ov': 1,
#                           'ev>ov>ev': 1,
#                           'ov>ev>o': 1,
#                           'ev>o>ev': 1,
#                           'o>ev>eo': 1,
#                           'ev>eo>o': 1,
#                           'eo>o>o': 1,
#                           'o>o>ceov': 1,
#                           'o>ceov>ceov': 1,
#                           'ceov>ceov>v': 1,
#                           'ceov>v>ev': 1,
#                           'v>ev>c': 1,
#                           'ev>c>v': 1,
#                           'c>v>ev': 1,
#                           'v>ev>ceov': 1,
#                           'ev>ceov>c': 1,
#                           'ceov>c>e': 1,
#                           'c>e>eov': 1,
#                           'e>eov>o': 1,
#                           'eov>o>e': 1,
#                           'o>e>v': 1,
#                           'e>v>v': 1,
#                           'v>v>c': 1,
#                           'v>c>c': 1,
#                           'c>c>ceov': 1,
#                           'c>ceov>co': 1,
#                           'ceov>co>o': 1,
#                           'co>o>e': 1,
#                           'o>e>c': 1,
#                           'e>c>ceov': 1,
#                           'c>ceov>ev': 1,
#                           'ceov>ev>ceov': 1,
#                           'ev>ceov>ceov': 1,
#                           'ceov>ceov>c': 1,
#                           'ceov>c>ev': 1,
#                           'c>ev>ceov': 1,
#                           'ev>ceov>eov': 1,
#                           'ceov>eov>eov': 1,
#                           'eov>eov>o': 1,
#                           'eov>o>ceov': 1,
#                           'o>ceov>c': 1,
#                           'ceov>c>eov': 1,
#                           'c>eov>ev': 1,
#                           'eov>ev>eov': 1}),
#              'f7aeae01-77f6-4fd9-bce8-14c1baaef954': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'e>v>ev': 1,
#                           'v>ev>ev': 1,
#                           'ev>ev>v': 1,
#                           'ev>v>e': 1,
#                           'v>e>ceov': 1,
#                           'e>ceov>ceov': 1,
#                           'ceov>ceov>cv': 1,
#                           'ceov>cv>ceov': 1,
#                           'cv>ceov>ceov': 1,
#                           'ceov>ceov>ceov': 2}),
#              'f7dbb768-ca66-40ac-8449-01773f9fbf3c': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>ov>ev': 1,
#                           'ov>ev>cv': 1,
#                           'ev>cv>c': 1,
#                           'cv>c>ev': 1,
#                           'c>ev>v': 1,
#                           'ev>v>v': 1,
#                           'v>v>ceov': 1,
#                           'v>ceov>ceov': 1,
#                           'ceov>ceov>ceov': 1,
#                           'ceov>ceov>ov': 1,
#                           'ceov>ov>o': 1,
#                           'ov>o>e': 2,
#                           'o>e>eov': 1,
#                           'e>eov>ov': 1,
#                           'eov>ov>o': 1,
#                           'o>e>e': 1}),
#              'f8598149-a52e-4088-ac92-947d0aefafad': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ov>o>ov': 1,
#                           'o>ov>c': 1,
#                           'ov>c>c': 1,
#                           'c>c>c': 1,
#                           'c>c>ov': 1,
#                           'c>ov>co': 1,
#                           'ov>co>ceov': 1,
#                           'co>ceov>ceov': 1}),
#              'f8704b44-06e5-4938-8c61-6a64aabf442b': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>v>e': 1,
#                           'v>e>v': 1,
#                           'e>v>e': 1,
#                           'v>e>ev': 1,
#                           'e>ev>e': 1,
#                           'ev>e>ceov': 1,
#                           'e>ceov>ev': 1,
#                           'ceov>ev>ov': 1,
#                           'ev>ov>v': 1,
#                           'ov>v>v': 1,
#                           'v>v>o': 1,
#                           'v>o>ceov': 1,
#                           'o>ceov>ceov': 1}),
#              'f9a0f1f6-1078-4ad8-b51b-2b62ec52e3e4': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>ceov>ceov': 5}),
#              'f9c3608a-b762-499c-a7b8-98546e3bc6e7': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>ceov>ev': 1,
#                           'ceov>ev>ev': 1,
#                           'ev>ev>co': 1,
#                           'ev>co>ev': 1,
#                           'co>ev>ev': 1,
#                           'ev>ev>cov': 1,
#                           'ev>cov>v': 1,
#                           'cov>v>c': 1,
#                           'v>c>c': 1,
#                           'c>c>cv': 1,
#                           'c>cv>v': 1,
#                           'cv>v>ov': 1,
#                           'v>ov>cv': 1,
#                           'ov>cv>ev': 1,
#                           'cv>ev>ev': 1,
#                           'ev>ev>eov': 1,
#                           'ev>eov>eov': 1,
#                           'eov>eov>o': 1,
#                           'eov>o>eov': 1,
#                           'o>eov>o': 1,
#                           'eov>o>v': 1,
#                           'o>v>o': 1,
#                           'v>o>ceov': 1,
#                           'o>ceov>e': 1,
#                           'ceov>e>eov': 1}),
#              'f9f884d0-a2d0-405a-bb05-477193e124e8': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>cv>ev': 1,
#                           'cv>ev>v': 1,
#                           'ev>v>ev': 1,
#                           'v>ev>e': 1,
#                           'ev>e>ceov': 1,
#                           'e>ceov>ceov': 1,
#                           'ceov>ceov>ceov': 3,
#                           'ceov>ceov>v': 2,
#                           'ceov>v>v': 2,
#                           'v>v>v': 3,
#                           'v>v>ceov': 1,
#                           'v>ceov>ceov': 1}),
#              'faa04f77-504c-46ae-9c04-db794102838a': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>v>ev': 1,
#                           'v>ev>ev': 1,
#                           'ev>ev>ev': 3,
#                           'ev>ev>c': 1,
#                           'ev>c>ev': 1,
#                           'c>ev>ev': 1}),
#              'fac1ef00-6500-4583-9d21-fb4dce54ea07': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>ce>ev': 1,
#                           'ce>ev>ev': 1,
#                           'ev>ev>c': 1,
#                           'ev>c>ev': 1,
#                           'c>ev>ceov': 1,
#                           'ev>ceov>ov': 1,
#                           'ceov>ov>eov': 1,
#                           'ov>eov>v': 1,
#                           'eov>v>v': 1,
#                           'v>v>v': 1,
#                           'v>v>ceov': 1,
#                           'v>ceov>ce': 1,
#                           'ceov>ce>v': 1,
#                           'ce>v>ov': 1,
#                           'v>ov>ov': 1,
#                           'ov>ov>ov': 3}),
#              'fb18014b-0af6-4ad4-a0d1-5d0458780d67': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ov>c>ev': 2,
#                           'c>ev>o': 1,
#                           'ev>o>e': 1,
#                           'o>e>e': 1,
#                           'e>e>e': 1,
#                           'e>e>ceov': 1,
#                           'e>ceov>o': 1,
#                           'ceov>o>ceov': 2,
#                           'o>ceov>ceov': 2,
#                           'ceov>ceov>e': 1,
#                           'ceov>e>ov': 1,
#                           'e>ov>c': 1,
#                           'c>ev>ceov': 1,
#                           'ev>ceov>o': 1,
#                           'ceov>ceov>ev': 1,
#                           'ceov>ev>e': 1,
#                           'ev>e>ev': 1,
#                           'e>ev>ov': 1,
#                           'ev>ov>eo': 1,
#                           'ov>eo>ceov': 1,
#                           'eo>ceov>ov': 1}),
#              'fbc45ae5-ec8f-4a42-98e1-47523af0c1c9': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'e>ev>ce': 1,
#                           'ev>ce>ev': 1,
#                           'ce>ev>cv': 1,
#                           'ev>cv>c': 1,
#                           'cv>c>cev': 1,
#                           'c>cev>ceov': 1,
#                           'cev>ceov>c': 1,
#                           'ceov>c>v': 1,
#                           'c>v>ov': 1,
#                           'v>ov>ov': 1}),
#              'fc5bb6ea-617a-4fb2-a4ba-03b9efca9769': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>ev>co': 1,
#                           'ev>co>o': 1,
#                           'co>o>ceov': 1,
#                           'o>ceov>c': 1,
#                           'ceov>c>ceov': 1,
#                           'c>ceov>c': 1,
#                           'ceov>c>c': 1,
#                           'c>c>e': 1,
#                           'c>e>e': 1,
#                           'e>e>o': 1,
#                           'e>o>o': 1,
#                           'o>o>o': 1,
#                           'o>o>ceov': 1,
#                           'o>ceov>o': 1,
#                           'ceov>o>v': 1,
#                           'o>v>v': 1,
#                           'v>v>ov': 1,
#                           'v>ov>ov': 1}),
#              'fc5d4829-92bf-481a-88dc-7e12a741176b': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>eo>c': 1,
#                           'eo>c>o': 1,
#                           'c>o>v': 1,
#                           'o>v>e': 1,
#                           'v>e>ov': 1}),
#              'fc842039-bdd8-49a0-ab8d-15b9f8fd608f': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>o>ov': 1,
#                           'o>ov>ev': 1,
#                           'ov>ev>o': 1,
#                           'ev>o>ceov': 1}),
#              'fdc97e18-6dcf-45cc-93b3-a3dff83aff2b': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>ov>o': 1}),
#              'fdf2d4d2-8c8d-4f54-bd1e-a513fb23f9f3': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>ov>v': 1,
#                           'ov>v>ov': 2,
#                           'v>ov>ov': 2,
#                           'ov>ov>v': 2}),
#              'fe0899f9-bfc2-495f-aa66-163c15908da7': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ceov>ev>ov': 1,
#                           'ev>ov>ev': 1,
#                           'ov>ev>ev': 1,
#                           'ev>ev>ev': 1,
#                           'ev>ev>o': 1,
#                           'ev>o>o': 1,
#                           'o>o>o': 1,
#                           'o>o>ov': 1,
#                           'o>ov>v': 1,
#                           'ov>v>ov': 2,
#                           'v>ov>v': 1,
#                           'ov>v>ceov': 1,
#                           'v>ceov>v': 1,
#                           'ceov>v>co': 1,
#                           'v>co>c': 1,
#                           'co>c>ov': 1,
#                           'c>ov>c': 1,
#                           'ov>c>v': 1,
#                           'c>v>o': 1,
#                           'v>o>ceov': 1,
#                           'o>ceov>e': 1,
#                           'ceov>e>ceov': 1,
#                           'e>ceov>ev': 1,
#                           'ceov>ev>co': 1,
#                           'ev>co>e': 1,
#                           'co>e>c': 1,
#                           'e>c>ceov': 1,
#                           'c>ceov>ov': 1,
#                           'ceov>ov>ceov': 1,
#                           'ov>ceov>ceov': 1,
#                           'ceov>ceov>ceov': 1,
#                           'ceov>ceov>v': 1,
#                           'ceov>v>v': 1,
#                           'v>v>ev': 1,
#                           'v>ev>v': 1,
#                           'ev>v>ceov': 1,
#                           'v>ceov>ceov': 1,
#                           'ceov>ceov>ev': 1,
#                           'ceov>ev>ceov': 1,
#                           'ev>ceov>ov': 1,
#                           'ceov>ov>v': 1}),
#              'fe58396a-e56f-46e4-b3c6-9150f8690895': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>e>v': 1,
#                           'e>v>e': 1,
#                           'v>e>ceov': 1,
#                           'e>ceov>ceov': 1,
#                           'ceov>ceov>v': 1}),
#              'fedfb026-19cd-4cf6-a8d4-04ca041c5291': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'ev>ceov>ov': 1,
#                           'ceov>ov>c': 1,
#                           'ov>c>ceov': 1,
#                           'c>ceov>c': 1,
#                           'ceov>c>v': 1,
#                           'c>v>ov': 1}),
#              'ff16fd69-1457-4f35-b4a2-f1dc30fdc346': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'v>ov>e': 1,
#                           'ov>e>v': 1,
#                           'e>v>cev': 1,
#                           'v>cev>v': 1,
#                           'cev>v>ev': 1,
#                           'v>ev>ov': 1,
#                           'ev>ov>v': 1,
#                           'ov>v>v': 2,
#                           'v>v>ev': 2,
#                           'v>ev>ev': 1,
#                           'ev>ev>e': 1,
#                           'ev>e>ov': 1,
#                           'e>ov>v': 1,
#                           'ov>v>ov': 1,
#                           'v>ov>v': 1,
#                           'v>v>v': 1,
#                           'v>ev>v': 2,
#                           'ev>v>ev': 1,
#                           'ev>v>v': 1,
#                           'v>v>e': 1,
#                           'v>e>ev': 1,
#                           'e>ev>ev': 1,
#                           'ev>ev>ceov': 1})})

# %%
room_to_performancegain = {}
message_count = {}
with open('meta_stats.tsv', 'r') as rf:
    tsv_reader = csv.reader(rf, delimiter='\t')
    next(tsv_reader)
    
    for item in tsv_reader:
        room_to_performancegain[item[0]] = float(item[-6])
        message_count[item[0]] = float(item[2])


# ordered = sorted(room_to_performancegain, key=room_to_performancegain.get, reverse=True)

positive_data = {}
negative_data = {}
neutral_data = {}
positive_bi = {}
negative_bi = {}
for key, item in all_transitions.items():
    if room_to_performancegain[key] > 0:
        positive_data[key] = item
        positive_bi[key] = item
    elif room_to_performancegain[key] < 0:
        negative_data[key] = item
        negative_bi[key] = item
    else:
        neutral_data[key] = item
    
for key, item in bi_transitions.items():
    if room_to_performancegain[key] > 0:
        positive_bi[key] = item
    elif room_to_performancegain[key] < 0:
        negative_bi[key] = item

# %%
def total_unique_normalised_count(collection, total_count=1):
    if len(collection) == 1 and len(collection[0][0]) < 3:
        return 0
    return len(collection)/total_count

def total_normalised_count(collection, total_count=1):
    if len(collection) == 1 and len(collection[0][0]) < 3:
        return 0
    total = sum([c for _, c in collection])
    return total / total_count

def repetitions(collection, total_count=1):
    rep = 0
    if len(collection) == 1 and len(collection[0][0]) < 3:
        return 0
    for (f, tt, t), count in collection:
        if len(set([f, tt, t])) == 1:
            rep += count
    return rep / total_count

def circular(collection, total_count=1):
    rep = 0
    if len(collection) == 1 and len(collection[0][0]) < 3:
        return 0
    for (f, tt, t), count in collection:
        if f == t and f != tt:
            rep += count
            
    return rep / total_count

def total_unique_solutions(collection, total_count=1):
    rep = 0
    unique = set()
    if len(collection) == 1 and len(collection[0][0][0]) == 0:
        return 0
    elif len(collection) == 1 and len(collection[0][0]) < 3:
        unique.update(collection[0][0])
        return len(unique) / total_count
    for (f, tt, t), count in collection:
        unique.add(f)
        unique.add(tt)        
        unique.add(t)
    return len(unique) / total_count

# %%
def get_probings_byroom(room_id, corpus):
    room = corpus[room_id]
    count_m, count_s, count_r = 0, 0, 0
    for room_message in room:
        if room_message['message_type'] == 'MESSAGE' and room_message['annotation_type'] == 'Probing':
            if room_message['annotation_target'] == 'Moderation':
                count_m += 1
            elif room_message['annotation_target'] == 'Reasoning':
                count_r += 1
            else:
                count_s += 1
            
    return count_m, count_s, count_r

def count_initials(room_id, corpus):
    obj = json.loads(corpus[room_id][0]['sol_tracker_all'])
    unique = set()
    count = 0
    for k, v in obj.items():
        unique.add("".join(v))
        count += 1
    
    return len(unique), count

# %%
positive_result = []
negative_result = []
neutral_result = []
for room, items in positive_data.items():
    states = []
    for k, i in items.items():
        states.append((k.split('>'), i))
#     m_c = message_count[room]
    m_c = 1 
    positive_result.append({'room_id': room, 'pg': room_to_performancegain[room],
                            'all_transitions': total_normalised_count(states, m_c),
                            'unique_transitions': total_unique_normalised_count(states, m_c),
                            'repetitions': repetitions(states, m_c),
                            'circular': circular(states, m_c),
                            'total_unique_sols': total_unique_solutions(states, m_c),
                            'message_count': message_count[room],
                            'probing_mod': get_probings_byroom(room, d)[0],
                            'probing_sol': get_probings_byroom(room, d)[1],
                            'probing_res': get_probings_byroom(room, d)[2],
                            'initial': count_initials(room, d)[0],
                            'participant_count': count_initials(room, d)[1]
                           })
    
for room, items in negative_data.items():
    states = []
    for k, i in items.items():
        states.append((k.split('>'), i))
#     m_c = message_count[room]
    m_c = 1 
    negative_result.append({'room_id': room, 'pg': room_to_performancegain[room],
                            'all_transitions': total_normalised_count(states, m_c),
                            'unique_transitions': total_unique_normalised_count(states, m_c),
                            'repetitions': repetitions(states, m_c),
                            'circular': circular(states, m_c),
                            'total_unique_sols': total_unique_solutions(states, m_c),
                            'message_count': message_count[room],
                            'probing_mod': get_probings_byroom(room, d)[0],
                            'probing_sol': get_probings_byroom(room, d)[1],
                            'probing_res': get_probings_byroom(room, d)[2],
                             'initial': count_initials(room, d)[0],
                            'participant_count': count_initials(room, d)[1]
                           })

    
for room, items in neutral_data.items():
    states = []
    for k, i in items.items():
        states.append((k.split('>'), i))
#     m_c = message_count[room]
    m_c = 1 
    neutral_result.append({'room_id': room, 'pg': room_to_performancegain[room],
                            'all_transitions': total_normalised_count(states, m_c),
                            'unique_transitions': total_unique_normalised_count(states, m_c),
                            'repetitions': repetitions(states, m_c),
                            'circular': circular(states, m_c),
                            'total_unique_sols': total_unique_solutions(states, m_c),
                            'message_count': message_count[room],
                            'probing_mod': get_probings_byroom(room, d)[0],
                            'probing_sol': get_probings_byroom(room, d)[1],
                            'probing_res': get_probings_byroom(room, d)[2],
                            'initial': count_initials(room, d)[0],
                            'participant_count': count_initials(room, d)[1]
                           })

# %%
print(len(positive_result), len(negative_result), len(neutral_result))
# Out:
# 318 82 100

# %% [markdown]
# # Predictive power

# %%
merged_data = [*positive_result, *negative_result, *neutral_result]
df = pd.DataFrame(merged_data)

# %%
df
# Out:
#                                   room_id        pg  all_transitions  \
# 0    0128a2aa-53a2-4874-8bfe-b71ce287e7c2  0.187500             26.0
# 1    01e7d47c-8831-4492-abb0-88f94c7b02a3  0.500000             16.0
# 2    02972b77-c909-499e-8d4b-8920a25707f0  0.083333             15.0
# 3    03714d9c-9c47-4103-9b61-ed51c76e1ef6  0.166667             10.0
# 4    038c3e5e-35bf-4e26-b96d-8ff92bb8c830  0.250000              5.0
# ..                                    ...       ...              ...
# 495  f241e2fb-4743-4e66-9152-f1103b54073f  0.000000              0.0
# 496  f2e7ae3f-ca02-4896-b0bf-b45caf4b8479  0.000000              7.0
# 497  f8704b44-06e5-4938-8c61-6a64aabf442b  0.000000             13.0
# 498  fb18014b-0af6-4ad4-a0d1-5d0458780d67  0.000000             24.0
# 499  fc842039-bdd8-49a0-ab8d-15b9f8fd608f  0.000000              4.0
#
#      unique_transitions  repetitions  circular  total_unique_sols  \
# 0                  26.0          0.0       4.0                7.0
# 1                  16.0          1.0       3.0                8.0
# 2                  12.0          1.0       5.0                6.0
# 3                  10.0          1.0       4.0                4.0
# 4                   5.0          0.0       2.0                4.0
# ..                  ...          ...       ...                ...
# 495                 0.0          0.0       0.0                2.0
# 496                 7.0          0.0       2.0                4.0
# 497                13.0          0.0       3.0                6.0
# 498                21.0          1.0       3.0                7.0
# 499                 4.0          0.0       0.0                4.0
#
#      message_count  probing_mod  probing_sol  probing_res  initial  \
# 0             64.0            0            0            2        3
# 1             30.0            1            0            4        3
# 2             54.0            2            5            0        3
# 3             18.0            0            0            3        4
# 4             21.0            2            1            1        3
# ..             ...          ...          ...          ...      ...
# 495           15.0            1            0            1        2
# 496           15.0            0            0            1        4
# 497           31.0            7            1            0        2
# 498           78.0            5            0            3        2
# 499           19.0            1            0            2        4
#
#      participant_count
# 0                    4
# 1                    5
# 2                    4
# 3                    4
# 4                    4
# ..                 ...
# 495                  4
# 496                  4
# 497                  4
# 498                  3
# 499                  5
#
# [500 rows x 13 columns]

# %%
df.describe()
# Out:
#                pg  all_transitions  unique_transitions  repetitions  \
# count  500.000000       500.000000          500.000000   500.000000
# mean     0.126700        10.566000            9.894000     0.860000
# std      0.195140         8.092009            7.541652     1.369727
# min     -0.666667         0.000000            0.000000     0.000000
# 25%      0.000000         5.000000            5.000000     0.000000
# 50%      0.125000         9.000000            8.000000     0.000000
# 75%      0.250000        15.000000           14.000000     1.000000
# max      0.750000        54.000000           50.000000    10.000000
#
#          circular  total_unique_sols  message_count  probing_mod  probing_sol  \
# count  500.000000         500.000000     500.000000   500.000000   500.000000
# mean     1.466000           5.124000      28.006000     1.570000     0.980000
# std      1.677639           2.230375      15.161455     1.476978     1.187611
# min      0.000000           0.000000       6.000000     0.000000     0.000000
# 25%      0.000000           3.000000      18.000000     0.000000     0.000000
# 50%      1.000000           5.000000      25.000000     1.000000     1.000000
# 75%      2.000000           7.000000      34.000000     2.000000     1.000000
# max     10.000000          11.000000     104.000000     8.000000     7.000000
#
#        probing_res     initial  participant_count
# count   500.000000  500.000000         500.000000
# mean      0.926000    3.090000           3.948000
# std       1.293007    0.929315           1.023421
# min       0.000000    1.000000           2.000000
# 25%       0.000000    2.000000           3.000000
# 50%       1.000000    3.000000           4.000000
# 75%       1.000000    4.000000           5.000000
# max       9.000000    6.000000           7.000000

# %%
# 0.126700	10.596000	9.924000	0.860000	1.466000	5.124000	28.006000

# %%
from scipy.stats import zscore

# %%
df[['all_transitions']] = df[['all_transitions']].transform(lambda x: zscore(x))
df[['circular']] = df[['circular']].transform(lambda x: zscore(x))
df[['message_count']] = df[['message_count']].transform(lambda x: zscore(x))
df[['repetitions']] = df[['repetitions']].transform(lambda x: zscore(x))
df[['total_unique_sols']] = df[['total_unique_sols']].transform(lambda x: zscore(x))
df[['unique_transitions']] = df[['unique_transitions']].transform(lambda x: zscore(x))
df[['probing_mod']] = df[['probing_mod']].transform(lambda x: zscore(x))
df[['probing_res']] = df[['probing_res']].transform(lambda x: zscore(x))
df[['probing_sol']] = df[['probing_sol']].transform(lambda x: zscore(x))

df[['pg']] = df[['pg']].transform(lambda x: zscore(x))

# %%
len(df[df['circular'] > 0])
# Out:
# 186

# %%
all_trans = ols("pg ~ total_unique_sols  + unique_transitions + circular + repetitions + message_count ", data=df).fit()
all_trans.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     pg   R-squared:                       0.107
# Model:                            OLS   Adj. R-squared:                  0.098
# Method:                 Least Squares   F-statistic:                     11.90
# Date:                Thu, 01 Feb 2024   Prob (F-statistic):           6.91e-11
# Time:                        20:38:28   Log-Likelihood:                -681.04
# No. Observations:                 500   AIC:                             1374.
# Df Residuals:                     494   BIC:                             1399.
# Df Model:                           5
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept          -5.378e-17      0.043  -1.27e-15      1.000      -0.084       0.084
# total_unique_sols      0.3162      0.078      4.073      0.000       0.164       0.469
# unique_transitions     0.0375      0.123      0.305      0.761      -0.204       0.279
# circular               0.1770      0.062      2.854      0.004       0.055       0.299
# repetitions            0.0439      0.047      0.927      0.354      -0.049       0.137
# message_count         -0.2352      0.081     -2.921      0.004      -0.393      -0.077
# ==============================================================================
# Omnibus:                       12.550   Durbin-Watson:                   0.825
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               21.376
# Skew:                          -0.135   Prob(JB):                     2.28e-05
# Kurtosis:                       3.976   Cond. No.                         6.10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Effect of probing on diversity

# %%
merged_data = [*positive_result, *negative_result, *neutral_result]
df_raw = pd.DataFrame(merged_data)

# %%
df_reduced = df_raw[df_raw['participant_count'] >= 3]
df_reduced = df_raw[df_raw['initial'] <= 2]
print(len(df_reduced))
df_reduced['probing'] = df_reduced['probing_sol'] + df_reduced['probing_mod'] + df_reduced['probing_res']
# Out:
# 135
# /var/folders/vp/7bwf0dxs2rd7_0tmxn77vx540000gn/T/ipykernel_69159/3244310022.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_reduced = df_reduced.drop('room_id', axis=1)

# %%
df_reduced.describe()
# Out:
#                pg  all_transitions  unique_transitions  repetitions  \
# count  135.000000       135.000000          135.000000   135.000000
# mean     0.085710         8.607407            8.022222     0.814815
# std      0.201278         6.862287            6.361576     1.383189
# min     -0.666667         0.000000            0.000000     0.000000
# 25%      0.000000         4.000000            4.000000     0.000000
# 50%      0.062500         7.000000            7.000000     0.000000
# 75%      0.187500        12.000000           11.500000     1.000000
# max      0.583333        42.000000           41.000000     7.000000
#
#          circular  total_unique_sols  message_count  probing_mod  probing_sol  \
# count  135.000000         135.000000     135.000000   135.000000   135.000000
# mean     1.229630           4.644444      26.170370     1.466667     0.755556
# std      1.583218           2.159556      14.754984     1.520016     1.003477
# min      0.000000           0.000000       7.000000     0.000000     0.000000
# 25%      0.000000           3.000000      17.000000     0.000000     0.000000
# 50%      1.000000           4.000000      22.000000     1.000000     1.000000
# 75%      2.000000           6.000000      33.000000     2.000000     1.000000
# max     10.000000          11.000000      86.000000     8.000000     7.000000
#
#        probing_res     initial  participant_count     probing
# count   135.000000  135.000000         135.000000  135.000000
# mean      0.711111    1.925926           3.111111    2.933333
# std       1.183636    0.262867           0.903283    2.369583
# min       0.000000    1.000000           2.000000    0.000000
# 25%       0.000000    2.000000           2.000000    1.000000
# 50%       0.000000    2.000000           3.000000    2.000000
# 75%       1.000000    2.000000           4.000000    4.000000
# max       7.000000    2.000000           5.000000   11.000000

# %%
df_reduced.corr() # 0.328990 0.424303
# Out:
#                           pg  all_transitions  unique_transitions  \
# pg                  1.000000         0.271750            0.272572
# all_transitions     0.271750         1.000000            0.984343
# unique_transitions  0.272572         0.984343            1.000000
# repetitions         0.060564         0.441216            0.318510
# circular            0.232166         0.687005            0.687093
# total_unique_sols   0.334456         0.742344            0.776280
# message_count       0.138371         0.832040            0.826806
# probing_mod        -0.079471         0.203712            0.208067
# probing_sol         0.009518         0.259058            0.291944
# probing_res         0.220606         0.337822            0.336838
# initial             0.015106         0.186474            0.175036
# participant_count   0.030861         0.280383            0.277487
# probing             0.063248         0.409128            0.425356
#
#                     repetitions  circular  total_unique_sols  message_count  \
# pg                     0.060564  0.232166           0.334456       0.138371
# all_transitions        0.441216  0.687005           0.742344       0.832040
# unique_transitions     0.318510  0.687093           0.776280       0.826806
# repetitions            1.000000  0.114981           0.112702       0.358440
# circular               0.114981  1.000000           0.340547       0.562798
# total_unique_sols      0.112702  0.340547           1.000000       0.592809
# message_count          0.358440  0.562798           0.592809       1.000000
# probing_mod            0.034312  0.110190           0.137316       0.307210
# probing_sol           -0.048987  0.275157           0.279857       0.243756
# probing_res            0.117501  0.230798           0.271905       0.444673
# initial                0.146714  0.059108           0.111011       0.120646
# participant_count      0.159943  0.169885           0.112219       0.203503
# probing                0.059958  0.302494           0.342418       0.522412
#
#                     probing_mod  probing_sol  probing_res   initial  \
# pg                    -0.079471     0.009518     0.220606  0.015106
# all_transitions        0.203712     0.259058     0.337822  0.186474
# unique_transitions     0.208067     0.291944     0.336838  0.175036
# repetitions            0.034312    -0.048987     0.117501  0.146714
# circular               0.110190     0.275157     0.230798  0.059108
# total_unique_sols      0.137316     0.279857     0.271905  0.111011
# message_count          0.307210     0.243756     0.444673  0.120646
# probing_mod            1.000000     0.080239     0.058900  0.031129
# probing_sol            0.080239     1.000000     0.185140  0.044009
# probing_res            0.058900     0.185140     1.000000  0.050635
# initial                0.031129     0.044009     0.050635  1.000000
# participant_count      0.168494     0.021955    -0.116333  0.097780
# probing                0.704871     0.567433     0.615699  0.063898
#
#                     participant_count   probing
# pg                           0.030861  0.063248
# all_transitions              0.280383  0.409128
# unique_transitions           0.277487  0.425356
# repetitions                  0.159943  0.059958
# circular                     0.169885  0.302494
# total_unique_sols            0.112219  0.342418
# message_count                0.203503  0.522412
# probing_mod                  0.168494  0.704871
# probing_sol                  0.021955  0.567433
# probing_res                 -0.116333  0.615699
# initial                      0.097780  0.063898
# participant_count            1.000000  0.059272
# probing                      0.059272  1.000000

# %%
import plotly.express as px

# %%
scatter = px.scatter(df_reduced,
                     x="total_unique_sols",
                     y="probing",
                     trendline="ols",
                     color_discrete_sequence=[COLOUR_ARRAY[3]])
fig = go.Figure(scatter)
fig.add_annotation(text='R-squared: 0.117<br>Correlation: 0.34', 
                    align='left',
                    showarrow=False,
                    xref='paper',
                    yref='paper',
                    x=1.06,
                    y=1,
                    bordercolor=COLOUR_ARRAY[3],
                    borderwidth=2, font = {'size':20})

fig.update_layout(
    xaxis_title="Number of unique solutions discussed", yaxis_title="Number of probing utterances"
)
fig.update_layout(font_size=20)
# fig.update_layout(width=1200)
fig.update_traces(marker=dict(size=10,
                              line=dict(width=2,
                                        )),
                  selector=dict(mode='markers'))

fig.show()


results = px.get_trendline_results(scatter)
print(results)

results.px_fit_results.iloc[0].summary()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_34.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
#                                       px_fit_results
# 0  <statsmodels.regression.linear_model.Regressio...
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.117
# Model:                            OLS   Adj. R-squared:                  0.111
# Method:                 Least Squares   F-statistic:                     17.67
# Date:                Thu, 01 Feb 2024   Prob (F-statistic):           4.80e-05
# Time:                        20:38:30   Log-Likelihood:                -299.10
# No. Observations:                 135   AIC:                             602.2
# Df Residuals:                     133   BIC:                             608.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1883      0.458      2.597      0.010       0.283       2.093
# x1             0.3757      0.089      4.203      0.000       0.199       0.553
# ==============================================================================
# Omnibus:                       31.403   Durbin-Watson:                   2.196
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.994
# Skew:                           1.164   Prob(JB):                     3.79e-11
# Kurtosis:                       4.764   Cond. No.                         12.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import plotly.io as pio

# Set the scale factor for resolution
# scale=1 corresponds to 96 dpi, scale=2 corresponds to 192 dpi, scale=3 corresponds to 288 dpi, and so on.
scale = 6  # Adjust this to control the resolution

filename = "probing_uniquesols.png"
pio.write_image(fig, filename, format='png', scale=scale)

# %%
all_trans = ols("total_unique_sols ~ probing_mod + probing_res + probing_sol ", data=df_reduced).fit()
all_trans.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      total_unique_sols   R-squared:                       0.140
# Model:                            OLS   Adj. R-squared:                  0.120
# Method:                 Least Squares   F-statistic:                     7.083
# Date:                Thu, 01 Feb 2024   Prob (F-statistic):           0.000190
# Time:                        20:38:32   Log-Likelihood:                -284.85
# No. Observations:                 135   AIC:                             577.7
# Df Residuals:                     131   BIC:                             589.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       3.7606      0.280     13.411      0.000       3.206       4.315
# probing_mod     0.1502      0.116      1.299      0.196      -0.079       0.379
# probing_res     0.4070      0.151      2.702      0.008       0.109       0.705
# probing_sol     0.4951      0.178      2.783      0.006       0.143       0.847
# ==============================================================================
# Omnibus:                        0.902   Durbin-Watson:                   1.700
# Prob(Omnibus):                  0.637   Jarque-Bera (JB):                1.019
# Skew:                           0.161   Prob(JB):                        0.601
# Kurtosis:                       2.722   Cond. No.                         4.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
